# %%
import pandas as pd, networkx as nx

# %%
## Reference network preparation 

HIPPIE_df=pd.read_csv("../Source/Interactomes/HIPPIE_v2_2.tab", keep_default_na=False, sep="\t")
print("The number of interaction in HIPPIE",len(HIPPIE_df.index))
HIPPIE_nx=nx.from_pandas_edgelist(HIPPIE_df,"Gene_1","Gene_2",edge_attr="Score")
self_interactions=list(nx.selfloop_edges(HIPPIE_nx))

# during permutation, we have to get rif off self interactions and nan-nan interaction, coming from reference network as a default.
for u, v in self_interactions:
    if isinstance(u, float):
        print(u)
    else:
        HIPPIE_nx.remove_edge(u,v)
    
#HIPPIE_nx.remove_edges_from(self_interactions)
HIPPIE_df=nx.to_pandas_edgelist(HIPPIE_nx)
print("The number of edges in HIPPIE network",HIPPIE_nx.number_of_edges())
print("The number of nodes in HIPPIE network",HIPPIE_nx.number_of_nodes())


edges=tuple(zip(HIPPIE_df.source,HIPPIE_df.target))
for edge in edges:
    if edge not in HIPPIE_nx.edges:
        print("check the edge",edge)
# Out:
# The number of interaction in HIPPIE 363336
# The number of edges in HIPPIE network 345770
# The number of nodes in HIPPIE network 15861

# %%
## initial nodes and weights 

initial_nodes_df=pd.read_csv(f'../Source/Netpath/Sampling_0_5/AndrogenReceptor_05A/AndrogenReceptor_05A_var_0.nodes',sep="\t")

initial_nodes=initial_nodes_df.name.to_list()
initial_weights=[1 for _ in initial_nodes]

# %%
from Paragon import GraphletFrequency

# %% [markdown]
# ## network permutation

# %%
GRF=GraphletFrequency(HIPPIE_nx,initial_nodes)

## network permutation once
Permutated_nx=GRF.permutate_network()
Permutated_df=nx.to_pandas_edgelist(Permutated_nx)
Permutated_df
GRF.save_permuted_network(f'../Source/Interactomes/Permuted/HIPPIE_permuted/HIPPIE_perm_4')
# Out:
# '../Source/Interactomes/Permuted/HIPPIE_permuted/HIPPIE_perm_4'

# %%
## Permutation of reference network multiple times (n permuted network)

GRF.save_permuted_networks(f_name=f'../Source/Interactomes/Permuted/HIPPIE_permuted/HIPPIE_prm',
                          size=100)
# Out:
# permuted network saved in	 ../Source/Interactomes/Permuted/HIPPIE_permuted/HIPPIE_prm_1
# permuted network saved in	 ../Source/Interactomes/Permuted/HIPPIE_permuted/HIPPIE_prm_2
# 1

# %% [markdown]
# # Graphlet Frequencies & Graphlet Gudided Network Construction
#
#
# we keep the statistical information of graphlets such as their interactions, frequencies etc

# %%
### Graphlet Frequencies

## frequencies from reference network

GRF=GraphletFrequency(HIPPIE_nx,initial_nodes)
Own_freq=pd.DataFrame([GRF.get_Graphlet_Frequency()])## GRF.get_Graphlet_Frequency() gives the frequencies in dict

### frequencies from permutated network 

Random_frequencies=GRF.get_frequencies_from_pool("../Source/Interactomes/Permuted/HIPPIE_permuted/")

#Random_frequencies


# Frequency calculations from permuted network might take long time depending on the network size. You can load the already calculated frequecies from pickle file 
#GRF.get_frequencies_from_pickle("../AndrogenReceptor_Pool_Frequencies.pickle")

# %%
GRF.get_Graphlet_Frequency()
# Out:
# {'Graphlets0': 0.0005076737368511812,
#  'Graphlets1': 0.03773616140713916,
#  'Graphlets2': 0.017971374374892223,
#  'Graphlets3': 0.5223535092257285,
#  'Graphlets4': 0.1784086911536472,
#  'Graphlets5': 0.08090774271426109,
#  'Graphlets6': 0.11248008277289188,
#  'Graphlets7': 0.03954750819106743,
#  'Graphlets8': 0.010087256423521297}

# %%
GRF.get_frequencies_from_pickle("../AndrogenReceptor_Pool_Frequencies.pickle")

# %% [markdown]
# ### Motif Selection
#
# We compare the frequencies of graphlets in reference network and its permutation

# %%
GRF.get_Z_score()
# Out:
# {'Graphlets0': (13.981109361276678, 1.0164711621330179e-44),
#  'Graphlets1': (-6.062503804298664, 6.700931865275906e-10),
#  'Graphlets2': (6.495700627660494, 4.13239318071793e-11),
#  'Graphlets3': (-5.605081828684537, 1.0407829941031376e-08),
#  'Graphlets4': (-1.0129980991920728, 0.15553053442595238),
#  'Graphlets5': (5.564931147547997, 1.311279695793731e-08),
#  'Graphlets6': (8.966223680736274, 1.5342723073451396e-19),
#  'Graphlets7': (12.928286830521651, 1.558433414973421e-38),
#  'Graphlets8': (11.280782284339463, 8.164371283260952e-30)}

# %% [markdown]
# #### Frequent graphlets

# %%
Selected_Graphlets=GRF.select_significant_Graphlets()

# %%
Selected_Graphlets.keys() # selected significant graphlets
# Out:
# dict_keys(['Graphlets0', 'Graphlets2', 'Graphlets5', 'Graphlets6', 'Graphlets7', 'Graphlets8'])

# %% [markdown]
# #### One by one, wee can list graphlets where  keys are composed of the node list and value is of the edge list.

# %%
Selected_Graphlets['Graphlets0']
# Out:
# {('APPL1', 'AR'): [('APPL1', 'AR')],
#  ('APPL1', 'PIK3R2'): [('APPL1', 'PIK3R2')],
#  ('APPL1', 'HSPB1'): [('APPL1', 'HSPB1')],
#  ('APPL1', 'AKT1'): [('APPL1', 'AKT1')],
#  ('APPL1', 'HDAC1'): [('APPL1', 'HDAC1')],
#  ('GAPDH', 'AR'): [('GAPDH', 'AR')],
#  ('GAPDH', 'MDM2'): [('GAPDH', 'MDM2')],
#  ('GAPDH', 'PXN'): [('GAPDH', 'PXN')],
#  ('GAPDH', 'JUN'): [('GAPDH', 'JUN')],
#  ('GAPDH', 'AKT1'): [('GAPDH', 'AKT1')],
#  ('GAPDH', 'RNF4'): [('GAPDH', 'RNF4')],
#  ('GAPDH', 'SIRT1'): [('GAPDH', 'SIRT1')],
#  ('GAPDH', 'BRCA1'): [('GAPDH', 'BRCA1')],
#  ('GAPDH', 'CDK5'): [('GAPDH', 'CDK5')],
#  ('GAPDH', 'ATF2'): [('GAPDH', 'ATF2')],
#  ('SP1', 'AR'): [('SP1', 'AR')],
#  ('SMAD3', 'SP1'): [('SP1', 'SMAD3')],
#  ('MDM2', 'SP1'): [('SP1', 'MDM2')],
#  ('SP1', 'JUN'): [('SP1', 'JUN')],
#  ('SRC', 'SP1'): [('SP1', 'SRC')],
#  ('SP1', 'RNF4'): [('SP1', 'RNF4')],
#  ('SIRT1', 'SP1'): [('SP1', 'SIRT1')],
#  ('DDX5', 'SP1'): [('SP1', 'DDX5')],
#  ('AHR', 'SP1'): [('SP1', 'AHR')],
#  ('NCOR1', 'SP1'): [('SP1', 'NCOR1')],
#  ('SP1', 'BRCA1'): [('SP1', 'BRCA1')],
#  ('ARNT', 'SP1'): [('SP1', 'ARNT')],
#  ('HDAC1', 'SP1'): [('SP1', 'HDAC1')],
#  ('SIN3A', 'SP1'): [('SP1', 'SIN3A')],
#  ('CDK1', 'SP1'): [('SP1', 'CDK1')],
#  ('PIK3R2', 'AR'): [('AR', 'PIK3R2')],
#  ('STUB1', 'AR'): [('AR', 'STUB1')],
#  ('CDK9', 'AR'): [('AR', 'CDK9')],
#  ('NCOA3', 'AR'): [('AR', 'NCOA3')],
#  ('HDAC7', 'AR'): [('AR', 'HDAC7')],
#  ('FKBP4', 'AR'): [('AR', 'FKBP4')],
#  ('SMAD3', 'AR'): [('AR', 'SMAD3')],
#  ('TCF4', 'AR'): [('AR', 'TCF4')],
#  ('MDM2', 'AR'): [('AR', 'MDM2')],
#  ('PXN', 'AR'): [('AR', 'PXN')],
#  ('NCOA2', 'AR'): [('AR', 'NCOA2')],
#  ('GTF2H3', 'AR'): [('AR', 'GTF2H3')],
#  ('TRIM68', 'AR'): [('AR', 'TRIM68')],
#  ('PARK7', 'AR'): [('AR', 'PARK7')],
#  ('RUNX2', 'AR'): [('AR', 'RUNX2')],
#  ('JUN', 'AR'): [('AR', 'JUN')],
#  ('NR2C2', 'AR'): [('AR', 'NR2C2')],
#  ('RNF14', 'AR'): [('AR', 'RNF14')],
#  ('SRC', 'AR'): [('AR', 'SRC')],
#  ('ZMIZ2', 'AR'): [('AR', 'ZMIZ2')],
#  ('RCHY1', 'AR'): [('AR', 'RCHY1')],
#  ('NCOA4', 'AR'): [('AR', 'NCOA4')],
#  ('CEBPA', 'AR'): [('AR', 'CEBPA')],
#  ('FOXA1', 'AR'): [('AR', 'FOXA1')],
#  ('BAG1', 'AR'): [('AR', 'BAG1')],
#  ('SLC25A4', 'AR'): [('AR', 'SLC25A4')],
#  ('AKT1', 'AR'): [('AR', 'AKT1')],
#  ('SMARCE1', 'AR'): [('AR', 'SMARCE1')],
#  ('PELP1', 'AR'): [('AR', 'PELP1')],
#  ('FOXO1', 'AR'): [('AR', 'FOXO1')],
#  ('RNF4', 'AR'): [('AR', 'RNF4')],
#  ('GSN', 'AR'): [('AR', 'GSN')],
#  ('SIRT1', 'AR'): [('AR', 'SIRT1')],
#  ('RAN', 'AR'): [('AR', 'RAN')],
#  ('AHR', 'AR'): [('AR', 'AHR')],
#  ('PIAS3', 'AR'): [('AR', 'PIAS3')],
#  ('PTEN', 'AR'): [('AR', 'PTEN')],
#  ('XRCC6', 'AR'): [('AR', 'XRCC6')],
#  ('NCOR1', 'AR'): [('AR', 'NCOR1')],
#  ('RBAK', 'AR'): [('AR', 'RBAK')],
#  ('BRCA1', 'AR'): [('AR', 'BRCA1')],
#  ('XRCC5', 'AR'): [('AR', 'XRCC5')],
#  ('GTF2H1', 'AR'): [('AR', 'GTF2H1')],
#  ('ERCC3', 'AR'): [('AR', 'ERCC3')],
#  ('NELFCD', 'AR'): [('AR', 'NELFCD')],
#  ('PSMC3IP', 'AR'): [('AR', 'PSMC3IP')],
#  ('UBE3A', 'AR'): [('AR', 'UBE3A')],
#  ('CASP8', 'AR'): [('AR', 'CASP8')],
#  ('TMF1', 'AR'): [('AR', 'TMF1')],
#  ('ATF2', 'AR'): [('AR', 'ATF2')],
#  ('IL6ST', 'AR'): [('AR', 'IL6ST')],
#  ('CDK7', 'AR'): [('AR', 'CDK7')],
#  ('HDAC1', 'AR'): [('AR', 'HDAC1')],
#  ('SIN3A', 'AR'): [('AR', 'SIN3A')],
#  ('GTF2H2', 'AR'): [('AR', 'GTF2H2')],
#  ('ETV5', 'AR'): [('AR', 'ETV5')],
#  ('PNRC1', 'AR'): [('AR', 'PNRC1')],
#  ('KAT2B', 'AR'): [('AR', 'KAT2B')],
#  ('KDM1A', 'AR'): [('AR', 'KDM1A')],
#  ('SPDEF', 'AR'): [('AR', 'SPDEF')],
#  ('NRIP1', 'AR'): [('AR', 'NRIP1')],
#  ('UXT', 'AR'): [('AR', 'UXT')],
#  ('TGFB1I1', 'AR'): [('AR', 'TGFB1I1')],
#  ('NR0B2', 'AR'): [('AR', 'NR0B2')],
#  ('PIK3R2', 'SRC'): [('PIK3R2', 'SRC')],
#  ('PIK3R2', 'AKT1'): [('PIK3R2', 'AKT1')],
#  ('PIK3R2', 'PRMT2'): [('PIK3R2', 'PRMT2')],
#  ('PIK3R2', 'PTEN'): [('PIK3R2', 'PTEN')],
#  ('STUB1', 'SMAD3'): [('STUB1', 'SMAD3')],
#  ('STUB1', 'PARK7'): [('STUB1', 'PARK7')],
#  ('STUB1', 'RUNX2'): [('STUB1', 'RUNX2')],
#  ('SRC', 'STUB1'): [('STUB1', 'SRC')],
#  ('STUB1', 'HSPB1'): [('STUB1', 'HSPB1')],
#  ('STUB1', 'BAG1'): [('STUB1', 'BAG1')],
#  ('STUB1', 'AKT1'): [('STUB1', 'AKT1')],
#  ('STUB1', 'FOXO1'): [('STUB1', 'FOXO1')],
#  ('STUB1', 'AHR'): [('STUB1', 'AHR')],
#  ('STUB1', 'PTEN'): [('STUB1', 'PTEN')],
#  ('STUB1', 'ERCC3'): [('STUB1', 'ERCC3')],
#  ('STUB1', 'CDK5'): [('STUB1', 'CDK5')],
#  ('CDK9', 'SMAD3'): [('CDK9', 'SMAD3')],
#  ('CDK9', 'MDM2'): [('CDK9', 'MDM2')],
#  ('CDK9', 'RCHY1'): [('CDK9', 'RCHY1')],
#  ('DDX5', 'CDK9'): [('CDK9', 'DDX5')],
#  ('CDK9', 'BRCA1'): [('CDK9', 'BRCA1')],
#  ('ARNT', 'CDK9'): [('CDK9', 'ARNT')],
#  ('CDK9', 'IL6ST'): [('CDK9', 'IL6ST')],
#  ('CDK9', 'CDK7'): [('CDK9', 'CDK7')],
#  ('SENP1', 'RNF4'): [('SENP1', 'RNF4')],
#  ('PIAS3', 'SENP1'): [('SENP1', 'PIAS3')],
#  ('HDAC1', 'SENP1'): [('SENP1', 'HDAC1')],
#  ('SMAD3', 'NCOA3'): [('NCOA3', 'SMAD3')],
#  ('NCOA2', 'NCOA3'): [('NCOA3', 'NCOA2')],
#  ('NCOA3', 'JUN'): [('NCOA3', 'JUN')],
#  ('NCOA3', 'FOXA1'): [('NCOA3', 'FOXA1')],
#  ('NCOA3', 'SMARCE1'): [('NCOA3', 'SMARCE1')],
#  ('DDX5', 'NCOA3'): [('NCOA3', 'DDX5')],
#  ('NCOA3', 'PTEN'): [('NCOA3', 'PTEN')],
#  ('NCOR1', 'NCOA3'): [('NCOA3', 'NCOR1')],
#  ('NCOA3', 'BRCA1'): [('NCOA3', 'BRCA1')],
#  ('XRCC5', 'NCOA3'): [('NCOA3', 'XRCC5')],
#  ('UBE3A', 'NCOA3'): [('NCOA3', 'UBE3A')],
#  ('KAT2B', 'NCOA3'): [('NCOA3', 'KAT2B')],
#  ('NCOA3', 'NR0B2'): [('NCOA3', 'NR0B2')],
#  ('RUNX2', 'HDAC7'): [('HDAC7', 'RUNX2')],
#  ('FOXA1', 'HDAC7'): [('HDAC7', 'FOXA1')],
#  ('NCOR1', 'HDAC7'): [('HDAC7', 'NCOR1')],
#  ('CASP8', 'HDAC7'): [('HDAC7', 'CASP8')],
#  ('HDAC1', 'HDAC7'): [('HDAC7', 'HDAC1')],
#  ('SIN3A', 'HDAC7'): [('HDAC7', 'SIN3A')],
#  ('MDM2', 'FKBP4'): [('FKBP4', 'MDM2')],
#  ('FKBP4', 'JUN'): [('FKBP4', 'JUN')],
#  ('FKBP4', 'HSPB1'): [('FKBP4', 'HSPB1')],
#  ('FKBP4', 'BRCA1'): [('FKBP4', 'BRCA1')],
#  ('RUNX2', 'SMAD3'): [('SMAD3', 'RUNX2')],
#  ('SMAD3', 'JUN'): [('SMAD3', 'JUN')],
#  ('SRC', 'SMAD3'): [('SMAD3', 'SRC')],
#  ('CEBPA', 'SMAD3'): [('SMAD3', 'CEBPA')],
#  ('SMAD3', 'FOXA1'): [('SMAD3', 'FOXA1')],
#  ('SMAD3', 'AKT1'): [('SMAD3', 'AKT1')],
#  ('FOXO1', 'SMAD3'): [('SMAD3', 'FOXO1')],
#  ('DDX5', 'SMAD3'): [('SMAD3', 'DDX5')],
#  ('PIAS3', 'SMAD3'): [('SMAD3', 'PIAS3')],
#  ('SMAD3', 'XRCC6'): [('SMAD3', 'XRCC6')],
#  ('SMAD3', 'BRCA1'): [('SMAD3', 'BRCA1')],
#  ('SMAD3', 'ATF2'): [('SMAD3', 'ATF2')],
#  ('HDAC1', 'SMAD3'): [('SMAD3', 'HDAC1')],
#  ('SIN3A', 'SMAD3'): [('SMAD3', 'SIN3A')],
#  ('KAT2B', 'SMAD3'): [('SMAD3', 'KAT2B')],
#  ('TGFB1I1', 'SMAD3'): [('SMAD3', 'TGFB1I1')],
#  ('TCF4', 'JUN'): [('TCF4', 'JUN')],
#  ('TCF4', 'RNF14'): [('TCF4', 'RNF14')],
#  ('TCF4', 'SMARCE1'): [('TCF4', 'SMARCE1')],
#  ('TCF4', 'KDM1A'): [('TCF4', 'KDM1A')],
#  ('MDM2', 'JUN'): [('MDM2', 'JUN')],
#  ('SRC', 'MDM2'): [('MDM2', 'SRC')],
#  ('RCHY1', 'MDM2'): [('MDM2', 'RCHY1')],
#  ('MDM2', 'HSPB1'): [('MDM2', 'HSPB1')],
#  ('SLC25A4', 'MDM2'): [('MDM2', 'SLC25A4')],
#  ('MDM2', 'AKT1'): [('MDM2', 'AKT1')],
#  ('MDM2', 'SMARCE1'): [('MDM2', 'SMARCE1')],
#  ('FOXO1', 'MDM2'): [('MDM2', 'FOXO1')],
#  ('MDM2', 'GSN'): [('MDM2', 'GSN')],
#  ('MDM2', 'SIRT1'): [('MDM2', 'SIRT1')],
#  ('TOP1', 'MDM2'): [('MDM2', 'TOP1')],
#  ('DDX5', 'MDM2'): [('MDM2', 'DDX5')],
#  ('RAN', 'MDM2'): [('MDM2', 'RAN')],
#  ('MDM2', 'XRCC6'): [('MDM2', 'XRCC6')],
#  ('XRCC5', 'MDM2'): [('MDM2', 'XRCC5')],
#  ('MDM2', 'UBE3A'): [('MDM2', 'UBE3A')],
#  ('HDAC1', 'MDM2'): [('MDM2', 'HDAC1')],
#  ('KAT2B', 'MDM2'): [('MDM2', 'KAT2B')],
#  ('MDM2', 'NR0B2'): [('MDM2', 'NR0B2')],
#  ('SRC', 'PXN'): [('PXN', 'SRC')],
#  ('GSN', 'PXN'): [('PXN', 'GSN')],
#  ('PTEN', 'PXN'): [('PXN', 'PTEN')],
#  ('ARNT', 'PXN'): [('PXN', 'ARNT')],
#  ('TGFB1I1', 'PXN'): [('PXN', 'TGFB1I1')],
#  ('PPA1', 'JUN'): [('PPA1', 'JUN')],
#  ('PPA1', 'HSPB1'): [('PPA1', 'HSPB1')],
#  ('PPA1', 'AKT1'): [('PPA1', 'AKT1')],
#  ('PPA1', 'BRCA1'): [('PPA1', 'BRCA1')],
#  ('ARNT', 'PPA1'): [('PPA1', 'ARNT')],
#  ('HDAC1', 'PPA1'): [('PPA1', 'HDAC1')],
#  ('NCOA2', 'JUN'): [('NCOA2', 'JUN')],
#  ('NCOA2', 'SMARCE1'): [('NCOA2', 'SMARCE1')],
#  ('DDX5', 'NCOA2'): [('NCOA2', 'DDX5')],
#  ('AHR', 'NCOA2'): [('NCOA2', 'AHR')],
#  ('PIAS3', 'NCOA2'): [('NCOA2', 'PIAS3')],
#  ('NCOA2', 'BRCA1'): [('NCOA2', 'BRCA1')],
#  ('ARNT', 'NCOA2'): [('NCOA2', 'ARNT')],
#  ('NCOA2', 'CCND3'): [('NCOA2', 'CCND3')],
#  ('GTF2H4', 'GTF2H3'): [('GTF2H3', 'GTF2H4')],
#  ('GTF2H1', 'GTF2H3'): [('GTF2H3', 'GTF2H1')],
#  ('ERCC3', 'GTF2H3'): [('GTF2H3', 'ERCC3')],
#  ('CDK7', 'GTF2H3'): [('GTF2H3', 'CDK7')],
#  ('GTF2H2', 'GTF2H3'): [('GTF2H3', 'GTF2H2')],
#  ('BAG1', 'PARK7'): [('PARK7', 'BAG1')],
#  ('PARK7', 'PTEN'): [('PARK7', 'PTEN')],
#  ('CASP8', 'PARK7'): [('PARK7', 'CASP8')],
#  ('HDAC1', 'PARK7'): [('PARK7', 'HDAC1')],
#  ('RUNX2', 'JUN'): [('RUNX2', 'JUN')],
#  ('RUNX2', 'XRCC6'): [('RUNX2', 'XRCC6')],
#  ('XRCC5', 'RUNX2'): [('RUNX2', 'XRCC5')],
#  ('HDAC1', 'RUNX2'): [('RUNX2', 'HDAC1')],
#  ('KAT2B', 'RUNX2'): [('RUNX2', 'KAT2B')],
#  ('RUNX2', 'NR0B2'): [('RUNX2', 'NR0B2')],
#  ('CEBPA', 'JUN'): [('JUN', 'CEBPA')],
#  ('SLC25A4', 'JUN'): [('JUN', 'SLC25A4')],
#  ('JUN', 'SMARCE1'): [('JUN', 'SMARCE1')],
#  ('SIRT1', 'JUN'): [('JUN', 'SIRT1')],
#  ('TOP1', 'JUN'): [('JUN', 'TOP1')],
#  ('DDX5', 'JUN'): [('JUN', 'DDX5')],
#  ('RAN', 'JUN'): [('JUN', 'RAN')],
#  ('JUN', 'XRCC6'): [('JUN', 'XRCC6')],
#  ('NCOR1', 'JUN'): [('JUN', 'NCOR1')],
#  ('JUN', 'BRCA1'): [('JUN', 'BRCA1')],
#  ('XRCC5', 'JUN'): [('JUN', 'XRCC5')],
#  ('ARNT', 'JUN'): [('JUN', 'ARNT')],
#  ('DBT', 'JUN'): [('JUN', 'DBT')],
#  ('JUN', 'ATF2'): [('JUN', 'ATF2')],
#  ('HDAC1', 'JUN'): [('JUN', 'HDAC1')],
#  ('KAT2B', 'JUN'): [('JUN', 'KAT2B')],
#  ('CDK1', 'JUN'): [('JUN', 'CDK1')],
#  ('KDM1A', 'JUN'): [('JUN', 'KDM1A')],
#  ('SF1', 'JUN'): [('JUN', 'SF1')],
#  ('NRIP1', 'JUN'): [('JUN', 'NRIP1')],
#  ('HDAC1', 'NR2C2'): [('NR2C2', 'HDAC1')],
#  ('KDM1A', 'NR2C2'): [('NR2C2', 'KDM1A')],
#  ('RNF14', 'NCOA4'): [('RNF14', 'NCOA4')],
#  ('SRC', 'AKT1'): [('SRC', 'AKT1')],
#  ('SRC', 'SMARCE1'): [('SRC', 'SMARCE1')],
#  ('SRC', 'PELP1'): [('SRC', 'PELP1')],
#  ('SRC', 'FOXO1'): [('SRC', 'FOXO1')],
#  ('SRC', 'GSN'): [('SRC', 'GSN')],
#  ('SRC', 'AHR'): [('SRC', 'AHR')],
#  ('SRC', 'BRCA1'): [('SRC', 'BRCA1')],
#  ('ARNT', 'SRC'): [('SRC', 'ARNT')],
#  ('SRC', 'CDK5'): [('SRC', 'CDK5')],
#  ('SRC', 'CASP8'): [('SRC', 'CASP8')],
#  ('SRC', 'KAT2B'): [('SRC', 'KAT2B')],
#  ('SRC', 'SF1'): [('SRC', 'SF1')],
#  ('ZMIZ2', 'SMARCE1'): [('ZMIZ2', 'SMARCE1')],
#  ('ZMIZ2', 'PIAS3'): [('ZMIZ2', 'PIAS3')],
#  ('RCHY1', 'BRCA1'): [('RCHY1', 'BRCA1')],
#  ('NCOA4', 'AKT1'): [('NCOA4', 'AKT1')],
#  ('KAT2B', 'NCOA4'): [('NCOA4', 'KAT2B')],
#  ('CEBPA', 'XRCC6'): [('CEBPA', 'XRCC6')],
#  ('XRCC5', 'CEBPA'): [('CEBPA', 'XRCC5')],
#  ('CEBPA', 'UBE3A'): [('CEBPA', 'UBE3A')],
#  ('CEBPA', 'ATF2'): [('CEBPA', 'ATF2')],
#  ('CEBPA', 'HDAC1'): [('CEBPA', 'HDAC1')],
#  ('AHR', 'FOXA1'): [('FOXA1', 'AHR')],
#  ('CDK1', 'FOXA1'): [('FOXA1', 'CDK1')],
#  ('SF1', 'FOXA1'): [('FOXA1', 'SF1')],
#  ('AKT1', 'HSPB1'): [('HSPB1', 'AKT1')],
#  ('RNF4', 'HSPB1'): [('HSPB1', 'RNF4')],
#  ('BRCA1', 'HSPB1'): [('HSPB1', 'BRCA1')],
#  ('XRCC5', 'HSPB1'): [('HSPB1', 'XRCC5')],
#  ('ARNT', 'HSPB1'): [('HSPB1', 'ARNT')],
#  ('ATF2', 'HSPB1'): [('HSPB1', 'ATF2')],
#  ('CDK1', 'HSPB1'): [('HSPB1', 'CDK1')],
#  ('TGFB1I1', 'HSPB1'): [('HSPB1', 'TGFB1I1')],
#  ('NCOR1', 'BAG1'): [('BAG1', 'NCOR1')],
#  ('FOXO1', 'AKT1'): [('AKT1', 'FOXO1')],
#  ('SIRT1', 'AKT1'): [('AKT1', 'SIRT1')],
#  ('DDX5', 'AKT1'): [('AKT1', 'DDX5')],
#  ('AKT1', 'PTEN'): [('AKT1', 'PTEN')],
#  ('AKT1', 'BRCA1'): [('AKT1', 'BRCA1')],
#  ('ARNT', 'AKT1'): [('AKT1', 'ARNT')],
#  ('CASP8', 'AKT1'): [('AKT1', 'CASP8')],
#  ('KAT2B', 'AKT1'): [('AKT1', 'KAT2B')],
#  ('NCOR1', 'SMARCE1'): [('SMARCE1', 'NCOR1')],
#  ('HDAC1', 'SMARCE1'): [('SMARCE1', 'HDAC1')],
#  ('SIN3A', 'SMARCE1'): [('SMARCE1', 'SIN3A')],
#  ('NR0B2', 'SMARCE1'): [('SMARCE1', 'NR0B2')],
#  ('PELP1', 'RNF4'): [('PELP1', 'RNF4')],
#  ('PELP1', 'KDM1A'): [('PELP1', 'KDM1A')],
#  ('FOXO1', 'SIRT1'): [('FOXO1', 'SIRT1')],
#  ('CDK1', 'FOXO1'): [('FOXO1', 'CDK1')],
#  ('TOP1', 'RNF4'): [('RNF4', 'TOP1')],
#  ('DDX5', 'RNF4'): [('RNF4', 'DDX5')],
#  ('PIAS3', 'RNF4'): [('RNF4', 'PIAS3')],
#  ('GTF2H4', 'RNF4'): [('RNF4', 'GTF2H4')],
#  ('RBAK', 'RNF4'): [('RNF4', 'RBAK')],
#  ('XRCC5', 'RNF4'): [('RNF4', 'XRCC5')],
#  ('SIN3A', 'RNF4'): [('RNF4', 'SIN3A')],
#  ('CDK1', 'RNF4'): [('RNF4', 'CDK1')],
#  ('SF1', 'RNF4'): [('RNF4', 'SF1')],
#  ('SF1', 'PRMT2'): [('PRMT2', 'SF1')],
#  ('PIAS3', 'SIRT1'): [('SIRT1', 'PIAS3')],
#  ('SIRT1', 'XRCC6'): [('SIRT1', 'XRCC6')],
#  ('NCOR1', 'SIRT1'): [('SIRT1', 'NCOR1')],
#  ('KAT2B', 'SIRT1'): [('SIRT1', 'KAT2B')],
#  ('CDK1', 'SIRT1'): [('SIRT1', 'CDK1')],
#  ('SIRT1', 'NR0B2'): [('SIRT1', 'NR0B2')],
#  ('DDX5', 'TOP1'): [('TOP1', 'DDX5')],
#  ('TOP1', 'XRCC6'): [('TOP1', 'XRCC6')],
#  ('TOP1', 'BRCA1'): [('TOP1', 'BRCA1')],
#  ('XRCC5', 'TOP1'): [('TOP1', 'XRCC5')],
#  ('DDX5', 'BRCA1'): [('DDX5', 'BRCA1')],
#  ('DDX5', 'HDAC1'): [('DDX5', 'HDAC1')],
#  ('DDX5', 'SF1'): [('DDX5', 'SF1')],
#  ('RAN', 'BRCA1'): [('RAN', 'BRCA1')],
#  ('RAN', 'SIN3A'): [('RAN', 'SIN3A')],
#  ('AHR', 'BRCA1'): [('AHR', 'BRCA1')],
#  ('ARNT', 'AHR'): [('AHR', 'ARNT')],
#  ('NRIP1', 'AHR'): [('AHR', 'NRIP1')],
#  ('HDAC1', 'PIAS3'): [('PIAS3', 'HDAC1')],
#  ('DBT', 'PTEN'): [('PTEN', 'DBT')],
#  ('CASP8', 'PTEN'): [('PTEN', 'CASP8')],
#  ('KAT2B', 'PTEN'): [('PTEN', 'KAT2B')],
#  ('BRCA1', 'XRCC6'): [('XRCC6', 'BRCA1')],
#  ('XRCC5', 'XRCC6'): [('XRCC6', 'XRCC5')],
#  ('ARNT', 'XRCC6'): [('XRCC6', 'ARNT')],
#  ('UBE3A', 'XRCC6'): [('XRCC6', 'UBE3A')],
#  ('KAT2B', 'XRCC6'): [('XRCC6', 'KAT2B')],
#  ('NCOR1', 'SIN3A'): [('NCOR1', 'SIN3A')],
#  ('GTF2H4', 'BRCA1'): [('GTF2H4', 'BRCA1')],
#  ('GTF2H4', 'GTF2H1'): [('GTF2H4', 'GTF2H1')],
#  ('GTF2H4', 'ERCC3'): [('GTF2H4', 'ERCC3')],
#  ('GTF2H4', 'CDK7'): [('GTF2H4', 'CDK7')],
#  ('GTF2H4', 'GTF2H2'): [('GTF2H4', 'GTF2H2')],
#  ('XRCC5', 'BRCA1'): [('BRCA1', 'XRCC5')],
#  ('ARNT', 'BRCA1'): [('BRCA1', 'ARNT')],
#  ('CDK5', 'BRCA1'): [('BRCA1', 'CDK5')],
#  ('UBE3A', 'BRCA1'): [('BRCA1', 'UBE3A')],
#  ('CDK7', 'BRCA1'): [('BRCA1', 'CDK7')],
#  ('HDAC1', 'BRCA1'): [('BRCA1', 'HDAC1')],
#  ('ETV5', 'BRCA1'): [('BRCA1', 'ETV5')],
#  ('CDK1', 'BRCA1'): [('BRCA1', 'CDK1')],
#  ('KDM1A', 'BRCA1'): [('BRCA1', 'KDM1A')],
#  ('NRIP1', 'BRCA1'): [('BRCA1', 'NRIP1')],
#  ('XRCC5', 'SF1'): [('XRCC5', 'SF1')],
#  ('GTF2H1', 'ERCC3'): [('GTF2H1', 'ERCC3')],
#  ('GTF2H1', 'CDK7'): [('GTF2H1', 'CDK7')],
#  ('GTF2H1', 'GTF2H2'): [('GTF2H1', 'GTF2H2')],
#  ('ARNT', 'HDAC1'): [('ARNT', 'HDAC1')],
#  ('ERCC3', 'CDK7'): [('ERCC3', 'CDK7')],
#  ('ERCC3', 'GTF2H2'): [('ERCC3', 'GTF2H2')],
#  ('NELFCD', 'UBE3A'): [('NELFCD', 'UBE3A')],
#  ('CDK5', 'CCND3'): [('CDK5', 'CCND3')],
#  ('CDK7', 'CDK5'): [('CDK5', 'CDK7')],
#  ('CASP8', 'PSMC3IP'): [('PSMC3IP', 'CASP8')],
#  ('CDK1', 'CCND3'): [('CCND3', 'CDK1')],
#  ('CDK1', 'UBE3A'): [('UBE3A', 'CDK1')],
#  ('HDAC1', 'KDM4C'): [('KDM4C', 'HDAC1')],
#  ('TMF1', 'KAT2B'): [('TMF1', 'KAT2B')],
#  ('CDK7', 'GTF2H2'): [('CDK7', 'GTF2H2')],
#  ('CDK1', 'CDK7'): [('CDK7', 'CDK1')],
#  ('SIN3A', 'HDAC1'): [('HDAC1', 'SIN3A')],
#  ('KDM1A', 'HDAC1'): [('HDAC1', 'KDM1A')],
#  ('NRIP1', 'HDAC1'): [('HDAC1', 'NRIP1')],
#  ('HDAC1', 'NR0B2'): [('HDAC1', 'NR0B2')],
#  ('KDM1A', 'SIN3A'): [('SIN3A', 'KDM1A')],
#  ('SIN3A', 'SF1'): [('SIN3A', 'SF1')],
#  ('SIN3A', 'NR0B2'): [('SIN3A', 'NR0B2')],
#  ('NRIP1', 'KAT2B'): [('KAT2B', 'NRIP1')]}

# %% [markdown]
# #### Greaphlet-Guided Network is composed of freqeuntly seen graphlets, motifs. Here, we can list edges in GGN.

# %%
GRF.get_selected_edge_list()
# Out:
# [('APPL1', 'AR'),
#  ('APPL1', 'PIK3R2'),
#  ('APPL1', 'HSPB1'),
#  ('APPL1', 'AKT1'),
#  ('APPL1', 'HDAC1'),
#  ('APPL1', 'TP53'),
#  ('APPL1', 'EGFR'),
#  ('APPL1', 'HDAC3'),
#  ('APPL1', 'HDAC2'),
#  ('APPL1', 'CTNNB1'),
#  ('APPL1', 'PIK3R1'),
#  ('APPL1', 'DCC'),
#  ('APPL1', 'SOCS6'),
#  ('APPL1', 'SH2D2A'),
#  ('APPL1', 'VCP'),
#  ('APPL1', 'NTRK1'),
#  ('APPL1', 'GNAI1'),
#  ('APPL1', 'CBLB'),
#  ('APPL1', 'LAMP1'),
#  ('APPL1', 'AKT2'),
#  ('APPL1', 'IGF1R'),
#  ('APPL1', 'CBL'),
#  ('APPL1', 'OCRL'),
#  ('APPL1', 'TGFBR1'),
#  ('APPL1', 'PIK3CA'),
#  ('APPL1', 'ACTN2'),
#  ('APPL1', 'PRKCZ'),
#  ('APPL1', 'UBE2N'),
#  ('APPL1', 'TUBB3'),
#  ('APPL1', 'RAB5A'),
#  ('APPL1', 'EEA1'),
#  ('APPL1', 'RHEBL1'),
#  ('APPL1', 'TRAF6'),
#  ('APPL1', 'RUVBL2'),
#  ('APPL1', 'MBD3'),
#  ('APPL1', 'DACT1'),
#  ('APPL1', 'GATAD2B'),
#  ('APPL1', 'RBBP7'),
#  ('APPL1', 'HDAC5'),
#  ('APPL1', 'RBBP4'),
#  ('APPL1', 'MTA2'),
#  ('APPL1', 'RTCB'),
#  ('APPL1', 'LARP1'),
#  ('APPL1', 'MAP3K1'),
#  ('APPL1', 'MYO6'),
#  ('APPL1', 'UBE2V1'),
#  ('APPL1', 'TRAF2'),
#  ('APPL1', 'UBA1'),
#  ('APPL1', 'ELAVL1'),
#  ('APPL1', 'DNM2'),
#  ('APPL1', 'RXRB'),
#  ('APPL1', 'AGL'),
#  ('APPL1', 'ID1'),
#  ('APPL1', 'CLTB'),
#  ('APPL1', 'ATP2A1'),
#  ('APPL1', 'SYNE2'),
#  ('APPL1', 'BATF3'),
#  ('APPL1', 'UBE2O'),
#  ('APPL1', 'LUC7L'),
#  ('APPL1', 'DOK2'),
#  ('APPL1', 'DTNA'),
#  ('APPL1', 'FSHR'),
#  ('APPL1', 'RAB5C'),
#  ('APPL1', 'BET1'),
#  ('APPL1', 'RAB21'),
#  ('APPL1', 'DYSF'),
#  ('APPL1', 'BIN1'),
#  ('APPL1', 'GIPC1'),
#  ('APPL1', 'FAM167A'),
#  ('APPL1', 'MYCBP2'),
#  ('APPL1', 'CLTA'),
#  ('APPL1', 'MEOX1'),
#  ('APPL1', 'TGOLN2'),
#  ('APPL1', 'KLF15'),
#  ('APPL1', 'ZNF829'),
#  ('AR', 'GAPDH'),
#  ('AR', 'SP1'),
#  ('AR', 'PIK3R2'),
#  ('AR', 'STUB1'),
#  ('AR', 'CDK9'),
#  ('AR', 'NCOA3'),
#  ('AR', 'HDAC7'),
#  ('AR', 'FKBP4'),
#  ('AR', 'SMAD3'),
#  ('AR', 'TCF4'),
#  ('AR', 'MDM2'),
#  ('AR', 'PXN'),
#  ('AR', 'NCOA2'),
#  ('AR', 'GTF2H3'),
#  ('AR', 'TRIM68'),
#  ('AR', 'PARK7'),
#  ('AR', 'RUNX2'),
#  ('AR', 'JUN'),
#  ('AR', 'NR2C2'),
#  ('AR', 'RNF14'),
#  ('AR', 'SRC'),
#  ('AR', 'ZMIZ2'),
#  ('AR', 'RCHY1'),
#  ('AR', 'NCOA4'),
#  ('AR', 'CEBPA'),
#  ('AR', 'FOXA1'),
#  ('AR', 'BAG1'),
#  ('AR', 'SLC25A4'),
#  ('AR', 'AKT1'),
#  ('AR', 'SMARCE1'),
#  ('AR', 'PELP1'),
#  ('AR', 'FOXO1'),
#  ('AR', 'RNF4'),
#  ('AR', 'GSN'),
#  ('AR', 'SIRT1'),
#  ('AR', 'RAN'),
#  ('AR', 'AHR'),
#  ('AR', 'PIAS3'),
#  ('AR', 'PTEN'),
#  ('AR', 'XRCC6'),
#  ('AR', 'NCOR1'),
#  ('AR', 'RBAK'),
#  ('AR', 'BRCA1'),
#  ('AR', 'XRCC5'),
#  ('AR', 'GTF2H1'),
#  ('AR', 'ERCC3'),
#  ('AR', 'NELFCD'),
#  ('AR', 'PSMC3IP'),
#  ('AR', 'UBE3A'),
#  ('AR', 'CASP8'),
#  ('AR', 'TMF1'),
#  ('AR', 'ATF2'),
#  ('AR', 'IL6ST'),
#  ('AR', 'CDK7'),
#  ('AR', 'HDAC1'),
#  ('AR', 'SIN3A'),
#  ('AR', 'GTF2H2'),
#  ('AR', 'ETV5'),
#  ('AR', 'PNRC1'),
#  ('AR', 'KAT2B'),
#  ('AR', 'KDM1A'),
#  ('AR', 'SPDEF'),
#  ('AR', 'NRIP1'),
#  ('AR', 'UXT'),
#  ('AR', 'TGFB1I1'),
#  ('AR', 'NR0B2'),
#  ('AR', 'TP53'),
#  ('AR', 'EGFR'),
#  ('AR', 'HDAC3'),
#  ('AR', 'HDAC2'),
#  ('AR', 'CTNNB1'),
#  ('AR', 'PIK3R1'),
#  ('AR', 'DCC'),
#  ('AR', 'SOCS6'),
#  ('AR', 'SH2D2A'),
#  ('AR', 'VCP'),
#  ('AR', 'EED'),
#  ('AR', 'YWHAQ'),
#  ('AR', 'PPP5C'),
#  ('AR', 'BLK'),
#  ('AR', 'HSP90AA1'),
#  ('AR', 'EP300'),
#  ('AR', 'CUL4B'),
#  ('AR', 'KARS1'),
#  ('AR', 'PRPF8'),
#  ('AR', 'GRB2'),
#  ('AR', 'PRKG1'),
#  ('AR', 'BTK'),
#  ('AR', 'NFKB1'),
#  ('AR', 'HSP90AB1'),
#  ('AR', 'HSPB2'),
#  ('AR', 'PPP2R2A'),
#  ('AR', 'SUMO1'),
#  ('AR', 'REL'),
#  ('AR', 'ESR1'),
#  ('AR', 'HDAC4'),
#  ('AR', 'PRDX1'),
#  ('AR', 'SVIL'),
#  ('AR', 'CUL2'),
#  ('AR', 'POU2F1'),
#  ('AR', 'ACTB'),
#  ('AR', 'GSK3B'),
#  ('AR', 'MAPK1'),
#  ('AR', 'SUMO2'),
#  ('AR', 'POU5F1'),
#  ('AR', 'POU2F2'),
#  ('AR', 'KAT5'),
#  ('AR', 'SRY'),
#  ('AR', 'SKP2'),
#  ('AR', 'CRK'),
#  ('AR', 'FHL2'),
#  ('AR', 'GAK'),
#  ('AR', 'HCK'),
#  ('AR', 'CASP7'),
#  ('AR', 'CASP3'),
#  ('AR', 'VHL'),
#  ('AR', 'CEBPB'),
#  ('AR', 'BCOR'),
#  ('AR', 'SFPQ'),
#  ('AR', 'SMARCA4'),
#  ('AR', 'TFAP2A'),
#  ('AR', 'SMAD4'),
#  ('AR', 'E2F1'),
#  ('AR', 'TBP'),
#  ('AR', 'ABL1'),
#  ('AR', 'HIF1A'),
#  ('AR', 'RBL1'),
#  ('AR', 'RB1'),
#  ('AR', 'KIF1A'),
#  ('AR', 'AATF'),
#  ('AR', 'DCAF6'),
#  ('AR', 'SMARCC2'),
#  ('AR', 'RELA'),
#  ('AR', 'NR5A1'),
#  ('AR', 'HNF4A'),
#  ('AR', 'SYK'),
#  ('AR', 'CCND1'),
#  ('AR', 'CREBBP'),
#  ('AR', 'MYCN'),
#  ('AR', 'SMARCC1'),
#  ('AR', 'ASH2L'),
#  ('AR', 'RUNX1'),
#  ('AR', 'PRKDC'),
#  ('AR', 'ETS1'),
#  ('AR', 'ZBTB16'),
#  ('AR', 'SHC1'),
#  ('AR', 'ZBTB7A'),
#  ('AR', 'STAT3'),
#  ('AR', 'IFI16'),
#  ('AR', 'SREBF1'),
#  ('AR', 'NCOR2'),
#  ('AR', 'PLCG2'),
#  ('AR', 'PIK3R3'),
#  ('AR', 'VAV2'),
#  ('AR', 'LCK'),
#  ('AR', 'INPPL1'),
#  ('AR', 'FGR'),
#  ('AR', 'PTPN11'),
#  ('AR', 'LYN'),
#  ('AR', 'PLCG1'),
#  ('AR', 'TPD52'),
#  ('AR', 'DAXX'),
#  ('AR', 'NR3C2'),
#  ('AR', 'ERG'),
#  ('AR', 'DNAJC7'),
#  ('AR', 'CDC37'),
#  ('AR', 'NR3C1'),
#  ('AR', 'PTGES3'),
#  ('AR', 'SMAD1'),
#  ('AR', 'EZH2'),
#  ('AR', 'RAF1'),
#  ('AR', 'PA2G4'),
#  ('AR', 'FKBP5'),
#  ('AR', 'RNF20'),
#  ('AR', 'CCNH'),
#  ('AR', 'BRD4'),
#  ('AR', 'SART3'),
#  ('AR', 'ARID3B'),
#  ('AR', 'RUVBL1'),
#  ('AR', 'YES1'),
#  ('AR', 'SRCAP'),
#  ('AR', 'IARS1'),
#  ('AR', 'POLR2A'),
#  ('AR', 'GTF2F1'),
#  ('AR', 'DPF2'),
#  ('AR', 'RNF40'),
#  ('AR', 'MED1'),
#  ('AR', 'SPOP'),
#  ('AR', 'PIAS1'),
#  ('AR', 'YWHAH'),
#  ('AR', 'PRMT1'),
#  ('AR', 'MAK'),
#  ('AR', 'NCOA1'),
#  ('AR', 'FOXG1'),
#  ('AR', 'GRIP1'),
#  ('AR', 'UBE2I'),
#  ('AR', 'PPP2CA'),
#  ('AR', 'TBL1XR1'),
#  ('AR', 'KDM5B'),
#  ('AR', 'FOXO3'),
#  ('AR', 'FES'),
#  ('AR', 'JUND'),
#  ('AR', 'KPNB1'),
#  ('AR', 'USP7'),
#  ('AR', 'FOXH1'),
#  ('AR', 'ZMIZ1'),
#  ('AR', 'E2F4'),
#  ('AR', 'FLNA'),
#  ('AR', 'PAX6'),
#  ('AR', 'TGIF1'),
#  ('AR', 'CDC25A'),
#  ('AR', 'TRIP4'),
#  ('AR', 'MED24'),
#  ('AR', 'CDC27'),
#  ('AR', 'ARID1A'),
#  ('AR', 'PIAS2'),
#  ('AR', 'RANBP9'),
#  ('AR', 'PIAS4'),
#  ('AR', 'PSPC1'),
#  ('AR', 'NCOA6'),
#  ('AR', 'CHD8'),
#  ('AR', 'TDG'),
#  ('AR', 'GSE1'),
#  ('AR', 'RNF6'),
#  ('AR', 'TRIM24'),
#  ('AR', 'SUZ12'),
#  ('AR', 'PSMC3'),
#  ('AR', 'USP10'),
#  ('AR', 'PRPF6'),
#  ('AR', 'DAPK3'),
#  ('AR', 'NSD2'),
#  ('AR', 'RNF2'),
#  ('AR', 'TSG101'),
#  ('AR', 'PPP1CA'),
#  ('AR', 'USP12'),
#  ('AR', 'ABL2'),
#  ('AR', 'USP26'),
#  ('AR', 'NONO'),
#  ('AR', 'SETD7'),
#  ('AR', 'TAF1'),
#  ('AR', 'LATS2'),
#  ('AR', 'HNRNPL'),
#  ('AR', 'COX5B'),
#  ('AR', 'ZNF318'),
#  ('AR', 'PAK6'),
#  ('AR', 'ZBTB1'),
#  ('AR', 'CALR'),
#  ('AR', 'SMARCA2'),
#  ('AR', 'MATK'),
#  ('AR', 'ADAM10'),
#  ('AR', 'GSK3A'),
#  ('AR', 'RASA1'),
#  ('AR', 'REPS2'),
#  ('AR', 'MAGEA11'),
#  ('AR', 'ERCC2'),
#  ('AR', 'GRAP2'),
#  ('AR', 'EFCAB6'),
#  ('AR', 'SMARCB1'),
#  ('AR', 'IDE'),
#  ('AR', 'KIFAP3'),
#  ('AR', 'BRD3'),
#  ('AR', 'RCC2'),
#  ('AR', 'RCOR1'),
#  ('AR', 'DAP3'),
#  ('AR', 'BRD2'),
#  ('AR', 'TCF20'),
#  ('AR', 'GTF2F2'),
#  ('AR', 'VAV1'),
#  ('AR', 'COPS2'),
#  ('AR', 'ELF3'),
#  ('AR', 'SMARCD1'),
#  ('AR', 'KAT7'),
#  ('AR', 'MYBBP1A'),
#  ('AR', 'PATZ1'),
#  ('AR', 'NR2C1'),
#  ('AR', 'TAB2'),
#  ('AR', 'SH2D3C'),
#  ('AR', 'BLNK'),
#  ('AR', 'TNK2'),
#  ('AR', 'CAV1'),
#  ('AR', 'SHB'),
#  ('AR', 'CDK6'),
#  ('AR', 'ASXL1'),
#  ('AR', 'KDM6A'),
#  ('AR', 'TLE3'),
#  ('AR', 'PPID'),
#  ('AR', 'MLH3'),
#  ('AR', 'CCNE1'),
#  ('AR', 'CTDSP2'),
#  ('AR', 'PRKCB'),
#  ('AR', 'BECN1'),
#  ('AR', 'HMGB1'),
#  ('AR', 'CHD7'),
#  ('AR', 'ARID1B'),
#  ('AR', 'SIN3B'),
#  ('AR', 'DPF1'),
#  ('AR', 'MDN1'),
#  ('AR', 'JMJD1C'),
#  ('AR', 'ARID5B'),
#  ('AR', 'ZNF451'),
#  ('AR', 'DDB2'),
#  ('AR', 'TCF7L2'),
#  ('AR', 'NEFL'),
#  ('AR', 'SIAH2'),
#  ('AR', 'BMI1'),
#  ('AR', 'PNRC2'),
#  ('AR', 'TADA3'),
#  ('AR', 'KDM4A'),
#  ('AR', 'RAD9A'),
#  ('AR', 'CASP1'),
#  ('AR', 'WDR48'),
#  ('AR', 'RAD54L2'),
#  ('AR', 'USP14'),
#  ('AR', 'CNBP'),
#  ('AR', 'SOCS3'),
#  ('AR', 'RREB1'),
#  ('AR', 'LCOR'),
#  ('AR', 'CDC25B'),
#  ('AR', 'NR0B1'),
#  ('AR', 'SH2D1B'),
#  ('AR', 'HIPK3'),
#  ('AR', 'WDR77'),
#  ('AR', 'NDE1'),
#  ('AR', 'WIPI1'),
#  ('AR', 'STAP1'),
#  ('PIK3R2', 'SRC'),
#  ('PIK3R2', 'AKT1'),
#  ('PIK3R2', 'PRMT2'),
#  ('PIK3R2', 'PTEN'),
#  ('PIK3R2', 'EGFR'),
#  ('PIK3R2', 'NTRK1'),
#  ('PIK3R2', 'GNAI1'),
#  ('PIK3R2', 'CBLB'),
#  ('PIK3R2', 'LAMP1'),
#  ('PIK3R2', 'AKT2'),
#  ('PIK3R2', 'IGF1R'),
#  ('PIK3R2', 'VCP'),
#  ('PIK3R2', 'SOCS6'),
#  ('PIK3R2', 'PIK3R1'),
#  ('PIK3R2', 'CBL'),
#  ('PIK3R2', 'OCRL'),
#  ('PIK3R2', 'TGFBR1'),
#  ('PIK3R2', 'PIK3CA'),
#  ('PIK3R2', 'YWHAQ'),
#  ('PIK3R2', 'CRK'),
#  ('PIK3R2', 'HCK'),
#  ('PIK3R2', 'PLCG2'),
#  ('PIK3R2', 'PIK3R3'),
#  ('PIK3R2', 'GRB2'),
#  ('PIK3R2', 'VAV2'),
#  ('PIK3R2', 'LCK'),
#  ('PIK3R2', 'INPPL1'),
#  ('PIK3R2', 'ABL1'),
#  ('PIK3R2', 'ESR1'),
#  ('PIK3R2', 'FGR'),
#  ('PIK3R2', 'PTPN11'),
#  ('PIK3R2', 'SYK'),
#  ('PIK3R2', 'LYN'),
#  ('PIK3R2', 'PLCG1'),
#  ('PIK3R2', 'ACTB'),
#  ('PIK3R2', 'SHC1'),
#  ('PIK3R2', 'STAT3'),
#  ('PIK3R2', 'MET'),
#  ('PIK3R2', 'CDC42'),
#  ('PIK3R2', 'SKAP1'),
#  ('PIK3R2', 'APP'),
#  ('PIK3R2', 'CSF1R'),
#  ('PIK3R2', 'JAK2'),
#  ('PIK3R2', 'AXL'),
#  ('PIK3R2', 'RRAS'),
#  ('PIK3R2', 'EFNB2'),
#  ('PIK3R2', 'PDK1'),
#  ('PIK3R2', 'ARRB1'),
#  ('PIK3R2', 'KIT'),
#  ('PIK3R2', 'BCR'),
#  ('PIK3R2', 'USP8'),
#  ('PIK3R2', 'PRKCI'),
#  ('PIK3R2', 'FYN'),
#  ('PIK3R2', 'FRS2'),
#  ('PIK3R2', 'PIK3CB'),
#  ('PIK3R2', 'ERBB3'),
#  ('PIK3R2', 'SOS1'),
#  ('PIK3R2', 'ABI1'),
#  ('PIK3R2', 'PTK2'),
#  ('PIK3R2', 'IQGAP1'),
#  ('PIK3R2', 'PIK3CD'),
#  ('PIK3R2', 'GAB1'),
#  ('PIK3R2', 'RAC2'),
#  ('PIK3R2', 'ERBB2'),
#  ('PIK3R2', 'PDPK1'),
#  ('PIK3R2', 'CD28'),
#  ('PIK3R2', 'FGFR2'),
#  ('PIK3R2', 'DLG1'),
#  ('PIK3R2', 'YWHAB'),
#  ('PIK3R2', 'GAB2'),
#  ('PIK3R2', 'FGFR1'),
#  ('PIK3R2', 'PDGFRB'),
#  ('PIK3R2', 'KRT10'),
#  ('PIK3R2', 'EGF'),
#  ('PIK3R2', 'KDR'),
#  ('PIK3R2', 'IRS1'),
#  ('PIK3R2', 'VCAM1'),
#  ('PIK3R2', 'MED28'),
#  ('PIK3R2', 'CSF2RB'),
#  ('PIK3R2', 'TUBB'),
#  ('PIK3R2', 'JAK3'),
#  ('PIK3R2', 'HTT'),
#  ('PIK3R2', 'AKT3'),
#  ('PIK3R2', 'HSPA8'),
#  ('PIK3R2', 'PI4K2B'),
#  ('PIK3R2', 'JAK1'),
#  ('PIK3R2', 'EPHA2'),
#  ('PIK3R2', 'NGFR'),
#  ('PIK3R2', 'SPTBN1'),
#  ('PIK3R2', 'HAVCR2'),
#  ('PIK3R2', 'HSPA6'),
#  ('PIK3R2', 'CRKL'),
#  ('PIK3R2', 'IRS4'),
#  ('PIK3R2', 'TUBA1C'),
#  ('PIK3R2', 'MYH10'),
#  ('PIK3R2', 'GNAI2'),
#  ('PIK3R2', 'ACACA'),
#  ('PIK3R2', 'HSPA1L'),
#  ('PIK3R2', 'KRT14'),
#  ('PIK3R2', 'MAPK6'),
#  ('PIK3R2', 'HAUS1'),
#  ('PIK3R2', 'SQSTM1'),
#  ('PIK3R2', 'CUL3'),
#  ('PIK3R2', 'ITGA4'),
#  ('PIK3R2', 'EEF1A1'),
#  ('PIK3R2', 'KRAS'),
#  ('PIK3R2', 'FUS'),
#  ('PIK3R2', 'ERBB4'),
#  ('PIK3R2', 'MYH9'),
#  ('PIK3R2', 'TGFBR2'),
#  ('PIK3R2', 'NXF1'),
#  ('PIK3R2', 'DDX3X'),
#  ('PIK3R2', 'MYH14'),
#  ('PIK3R2', 'EGLN3'),
#  ('PIK3R2', 'MOV10'),
#  ('PIK3R2', 'GHR'),
#  ('PIK3R2', 'TUBB6'),
#  ('PIK3R2', 'RPS5'),
#  ('PIK3R2', 'GNB2'),
#  ('PIK3R2', 'GRN'),
#  ('PIK3R2', 'INPP5E'),
#  ('PIK3R2', 'IKZF3'),
#  ('PIK3R2', 'LMNA'),
#  ('PIK3R2', 'KRT2'),
#  ('PIK3R2', 'MRFAP1L1'),
#  ('PIK3R2', 'PTGER3'),
#  ('PIK3R2', 'KRT1'),
#  ('PIK3R2', 'GOLGA2'),
#  ('PIK3R2', 'KRT9'),
#  ('PIK3R2', 'KRT5'),
#  ('PIK3R2', 'RPS10'),
#  ('PIK3R2', 'KRT17'),
#  ('PIK3R2', 'RPS7'),
#  ('PIK3R2', 'TRIM23'),
#  ('PIK3R2', 'FLT1'),
#  ('PIK3R2', 'DNM1L'),
#  ('PIK3R2', 'PIP4K2A'),
#  ('PIK3R2', 'SEPTIN2'),
#  ('PIK3R2', 'SEMG1'),
#  ('PIK3R2', 'CORO1C'),
#  ('PIK3R2', 'KRT15'),
#  ('PIK3R2', 'RINT1'),
#  ('PIK3R2', 'PIP5K1A'),
#  ('PIK3R2', 'LAMB2'),
#  ('PIK3R2', 'CDIPT'),
#  ('PIK3R2', 'IRS2'),
#  ('PIK3R2', 'KRT79'),
#  ('PIK3R2', 'SOCS1'),
#  ('PIK3R2', 'SOCS7'),
#  ('PIK3R2', 'PI4KB'),
#  ('PIK3R2', 'CCR5'),
#  ('PIK3R2', 'PLCB4'),
#  ('PIK3R2', 'KRT38'),
#  ('PIK3R2', 'IL3RA'),
#  ('PIK3R2', 'ZAP70'),
#  ('HSPB1', 'STUB1'),
#  ('HSPB1', 'FKBP4'),
#  ('HSPB1', 'MDM2'),
#  ('HSPB1', 'PPA1'),
#  ('HSPB1', 'AKT1'),
#  ('HSPB1', 'RNF4'),
#  ('HSPB1', 'BRCA1'),
#  ('HSPB1', 'XRCC5'),
#  ('HSPB1', 'ARNT'),
#  ('HSPB1', 'ATF2'),
#  ('HSPB1', 'CDK1'),
#  ('HSPB1', 'TGFB1I1'),
#  ('HSPB1', 'TP53'),
#  ('HSPB1', 'EGFR'),
#  ('HSPB1', 'NTRK1'),
#  ('HSPB1', 'ACTN2'),
#  ('HSPB1', 'PRKCZ'),
#  ('HSPB1', 'CTNNB1'),
#  ('HSPB1', 'UBE2N'),
#  ('HSPB1', 'TUBB3'),
#  ('HSPB1', 'VCP'),
#  ('HSPB1', 'MYC'),
#  ('HSPB1', 'PAICS'),
#  ('HSPB1', 'DAXX'),
#  ('HSPB1', 'MAPK6'),
#  ('HSPB1', 'HDAC6'),
#  ('HSPB1', 'HSP90AA1'),
#  ('HSPB1', 'RIPK4'),
#  ('HSPB1', 'MAP3K7'),
#  ('HSPB1', 'ARAF'),
#  ('HSPB1', 'PRPF8'),
#  ('HSPB1', 'HSP90AB1'),
#  ('HSPB1', 'TRIM25'),
#  ('HSPB1', 'HSF1'),
#  ('HSPB1', 'SIM2'),
#  ('HSPB1', 'PRPF19'),
#  ('HSPB1', 'PCSK9'),
#  ('HSPB1', 'SQSTM1'),
#  ('HSPB1', 'CHUK'),
#  ('HSPB1', 'SNCA'),
#  ('HSPB1', 'HSPA4'),
#  ('HSPB1', 'OLA1'),
#  ('HSPB1', 'ESR1'),
#  ('HSPB1', 'PSMA3'),
#  ('HSPB1', 'TGFB1'),
#  ('HSPB1', 'HDAC4'),
#  ('HSPB1', 'PSMD1'),
#  ('HSPB1', 'CFTR'),
#  ('HSPB1', 'TUBA1A'),
#  ('HSPB1', 'IRAK1'),
#  ('HSPB1', 'LRRK2'),
#  ('HSPB1', 'ILK'),
#  ('HSPB1', 'MTCH2'),
#  ('HSPB1', 'PTGES3'),
#  ('HSPB1', 'HSPA9'),
#  ('HSPB1', 'HSPA8'),
#  ('HSPB1', 'EZH2'),
#  ('HSPB1', 'YAP1'),
#  ('HSPB1', 'SUMO2'),
#  ('HSPB1', 'ASB10'),
#  ('HSPB1', 'BAG3'),
#  ('HSPB1', 'ASB4'),
#  ('HSPB1', 'TRIM14'),
#  ('HSPB1', 'NOS2'),
#  ('HSPB1', 'MCM2'),
#  ('HSPB1', 'YWHAZ'),
#  ('HSPB1', 'CSNK2A1'),
#  ('HSPB1', 'TPM3'),
#  ('HSPB1', 'IKBKB'),
#  ('HSPB1', 'SMURF2'),
#  ('HSPB1', 'STIP1'),
#  ('HSPB1', 'VCAM1'),
#  ('HSPB1', 'CDC73'),
#  ('HSPB1', 'GLMN'),
#  ('HSPB1', 'AHNAK'),
#  ('HSPB1', 'RAD23A'),
#  ('HSPB1', 'HUWE1'),
#  ('HSPB1', 'TPT1'),
#  ('HSPB1', 'EEF1D'),
#  ('HSPB1', 'OXCT1'),
#  ('HSPB1', 'TOMM70'),
#  ('HSPB1', 'PKM'),
#  ('HSPB1', 'UQCRB'),
#  ('HSPB1', 'CSNK2A2'),
#  ('HSPB1', 'KRT18'),
#  ('HSPB1', 'HDLBP'),
#  ('HSPB1', 'MDH2'),
#  ('HSPB1', 'ACTN1'),
#  ('HSPB1', 'SF3B3'),
#  ('HSPB1', 'HNRNPF'),
#  ('HSPB1', 'ZBTB1'),
#  ('HSPB1', 'EEF1A1'),
#  ('HSPB1', 'CALR'),
#  ('HSPB1', 'MAPKAPK2'),
#  ('HSPB1', 'RPL6'),
#  ('HSPB1', 'SF3A3'),
#  ('HSPB1', 'PTBP1'),
#  ('HSPB1', 'UBE2I'),
#  ('HSPB1', 'HNRNPH1'),
#  ('HSPB1', 'S100A4'),
#  ('HSPB1', 'PAF1'),
#  ('HSPB1', 'CDK5RAP3'),
#  ('HSPB1', 'G6PD'),
#  ('HSPB1', 'ARHGDIA'),
#  ('HSPB1', 'RPSA'),
#  ('HSPB1', 'HNRNPA2B1'),
#  ('HSPB1', 'ERP29'),
#  ('HSPB1', 'WWOX'),
#  ('HSPB1', 'SRRM2'),
#  ('HSPB1', 'EFTUD2'),
#  ('HSPB1', 'CASP3'),
#  ('HSPB1', 'CS'),
#  ('HSPB1', 'FLNB'),
#  ('HSPB1', 'MAP1LC3A'),
#  ('HSPB1', 'SUMO1'),
#  ('HSPB1', 'JUP'),
#  ('HSPB1', 'RBM39'),
#  ('HSPB1', 'COPS5'),
#  ('HSPB1', 'TUBA1C'),
#  ('HSPB1', 'HNRNPU'),
#  ('HSPB1', 'PPT1'),
#  ('HSPB1', 'MRPS23'),
#  ('HSPB1', 'TUBA4A'),
#  ('HSPB1', 'NAP1L1'),
#  ('HSPB1', 'SMARCA2'),
#  ('HSPB1', 'VIM'),
#  ('HSPB1', 'YWHAQ'),
#  ('HSPB1', 'NEDD8'),
#  ('HSPB1', 'RYBP'),
#  ('HSPB1', 'TKT'),
#  ('HSPB1', 'ANG'),
#  ('HSPB1', 'SMARCA4'),
#  ('HSPB1', 'IPO7'),
#  ('HSPB1', 'XPO1'),
#  ('HSPB1', 'ACTN4'),
#  ('HSPB1', 'HNRNPH2'),
#  ('HSPB1', 'BTRC'),
#  ('HSPB1', 'NPM1'),
#  ('HSPB1', 'EIF4G1'),
#  ('HSPB1', 'HNRNPA1'),
#  ('HSPB1', 'BUB1B'),
#  ('HSPB1', 'PSMC1'),
#  ('HSPB1', 'PRDX6'),
#  ('HSPB1', 'HNRNPD'),
#  ('HSPB1', 'PSMA6'),
#  ('HSPB1', 'FN1'),
#  ('HSPB1', 'ITPA'),
#  ('HSPB1', 'GLO1'),
#  ('HSPB1', 'PIH1D1'),
#  ('HSPB1', 'DUT'),
#  ('HSPB1', 'NFKBIA'),
#  ('HSPB1', 'CCND2'),
#  ('HSPB1', 'ARHGEF7'),
#  ('HSPB1', 'BRAF'),
#  ('HSPB1', 'CARHSP1'),
#  ('HSPB1', 'YWHAE'),
#  ('HSPB1', 'TTC3'),
#  ('HSPB1', 'MAPK14'),
#  ('HSPB1', 'BCL2L1'),
#  ('HSPB1', 'PTPN3'),
#  ('HSPB1', 'CYLD'),
#  ('HSPB1', 'GATA1'),
#  ('HSPB1', 'USP1'),
#  ('HSPB1', 'STK4'),
#  ('HSPB1', 'PPM1A'),
#  ('HSPB1', 'GET4'),
#  ('HSPB1', 'PRPF40A'),
#  ('HSPB1', 'GNPAT'),
#  ('HSPB1', 'FLNC'),
#  ('HSPB1', 'RPA1'),
#  ('HSPB1', 'TARDBP'),
#  ('HSPB1', 'SPTBN1'),
#  ('HSPB1', 'PSMD6'),
#  ('HSPB1', 'RRP1B'),
#  ('HSPB1', 'HNRNPH3'),
#  ('HSPB1', 'RIF1'),
#  ('HSPB1', 'TSC22D1'),
#  ('HSPB1', 'GAPVD1'),
#  ('HSPB1', 'CYCS'),
#  ('HSPB1', 'CCNT1'),
#  ('HSPB1', 'PHLDA1'),
#  ('HSPB1', 'SLX4'),
#  ('HSPB1', 'CBX1'),
#  ('HSPB1', 'MAGED1'),
#  ('HSPB1', 'SNRNP200'),
#  ('HSPB1', 'LONRF1'),
#  ('HSPB1', 'UCHL5'),
#  ('HSPB1', 'ECPAS'),
#  ('HSPB1', 'GRPEL1'),
#  ('HSPB1', 'PHF12'),
#  ('HSPB1', 'TRIM24'),
#  ('HSPB1', 'RPAP3'),
#  ('HSPB1', 'SUPT5H'),
#  ('HSPB1', 'AHCY'),
#  ('HSPB1', 'RBX1'),
#  ('HSPB1', 'PALLD'),
#  ('HSPB1', 'SRP72'),
#  ('HSPB1', 'MSN'),
#  ('HSPB1', 'EIF3M'),
#  ('HSPB1', 'DES'),
#  ('HSPB1', 'KPNA4'),
#  ('HSPB1', 'GMPS'),
#  ('HSPB1', 'ARIH1'),
#  ('HSPB1', 'ERCC5'),
#  ('HSPB1', 'CDC5L'),
#  ('HSPB1', 'RPA3'),
#  ('HSPB1', 'RPA2'),
#  ('HSPB1', 'EEF1B2'),
#  ('HSPB1', 'POLD1'),
#  ('HSPB1', 'SEC13'),
#  ('HSPB1', 'EIF4A2'),
#  ('HSPB1', 'NSMCE4A'),
#  ('HSPB1', 'MYL12A'),
#  ('HSPB1', 'EIF2S1'),
#  ('HSPB1', 'LUZP1'),
#  ('HSPB1', 'AP2B1'),
#  ('HSPB1', 'STRN'),
#  ('HSPB1', 'ANXA1'),
#  ('HSPB1', 'TARS1'),
#  ('HSPB1', 'MCM6'),
#  ('HSPB1', 'OBSL1'),
#  ('HSPB1', 'CUL3'),
#  ('HSPB1', 'ISG15'),
#  ('HSPB1', 'PTBP3'),
#  ('HSPB1', 'GABARAPL2'),
#  ('HSPB1', 'EIF4B'),
#  ('HSPB1', 'SOX2'),
#  ('HSPB1', 'WWP1'),
#  ('HSPB1', 'KRAS'),
#  ('HSPB1', 'TYK2'),
#  ('HSPB1', 'ITGA4'),
#  ('HSPB1', 'MAP1LC3B'),
#  ('HSPB1', 'MME'),
#  ('HSPB1', 'KLC1'),
#  ('HSPB1', 'RPS6KA5'),
#  ('HSPB1', 'YWHAB'),
#  ('HSPB1', 'MAPKAPK5'),
#  ('HSPB1', 'TES'),
#  ('HSPB1', 'DLST'),
#  ('HSPB1', 'SNW1'),
#  ('HSPB1', 'USP14'),
#  ('HSPB1', 'CRK'),
#  ('HSPB1', 'GRB2'),
#  ('HSPB1', 'YWHAH'),
#  ('HSPB1', 'SMARCD1'),
#  ('HSPB1', 'HAUS1'),
#  ('HSPB1', 'IRS4'),
#  ('HSPB1', 'PFDN2'),
#  ('HSPB1', 'RBPJ'),
#  ('HSPB1', 'CRYAB'),
#  ('HSPB1', 'E2F6'),
#  ('HSPB1', 'MAGEA6'),
#  ('HSPB1', 'HINFP'),
#  ('HSPB1', 'DMAP1'),
#  ('HSPB1', 'STAT2'),
#  ('HSPB1', 'SAP18'),
#  ('HSPB1', 'NUP98'),
#  ('HSPB1', 'ACTC1'),
#  ('HSPB1', 'SMN1; SMN2'),
#  ('HSPB1', 'CAMK1'),
#  ('HSPB1', 'IQCB1'),
#  ('HSPB1', 'DFFA'),
#  ('HSPB1', 'GABARAPL1'),
#  ('HSPB1', 'GLOD4'),
#  ('HSPB1', 'PRKCD'),
#  ('HSPB1', 'MYL9'),
#  ('HSPB1', 'SERTAD1'),
#  ('HSPB1', 'RSPH3'),
#  ('HSPB1', 'PLG'),
#  ('HSPB1', 'LBP'),
#  ('HSPB1', 'KANSL1'),
#  ('HSPB1', 'UBA2'),
#  ('HSPB1', 'PDHA1'),
#  ('HSPB1', 'PTPRA'),
#  ('HSPB1', 'MAPKAPK3'),
#  ('HSPB1', 'MAP2K1'),
#  ('HSPB1', 'EPB41L3'),
#  ('HSPB1', 'MYLK'),
#  ('HSPB1', 'ISG20L2'),
#  ('HSPB1', 'PRKD1'),
#  ('HSPB1', 'KCTD3'),
#  ('HSPB1', 'ANAPC7'),
#  ('HSPB1', 'AATK'),
#  ('HSPB1', 'INS'),
#  ('HSPB1', 'PELO'),
#  ('HSPB1', 'CCNC'),
#  ('HSPB1', 'UBL4A'),
#  ('HSPB1', 'MSL1'),
#  ('HSPB1', 'ALPI'),
#  ('HSPB1', 'POP7'),
#  ('HSPB1', 'ADD3'),
#  ('HSPB1', 'MRPL40'),
#  ('HSPB1', 'SARS1'),
#  ('HSPB1', 'FXR1'),
#  ('HSPB1', 'NCKIPSD'),
#  ('HSPB1', 'EIF5'),
#  ('HSPB1', 'WDR83'),
#  ('HSPB1', 'GDI2'),
#  ('HSPB1', 'NRDC'),
#  ('HSPB1', 'AGAP3'),
#  ('HSPB1', 'ZYX'),
#  ('HSPB1', 'CPSF3'),
#  ('HSPB1', 'CRNKL1'),
#  ('HSPB1', 'CCNDBP1'),
#  ('HSPB1', 'RBM25'),
#  ('HSPB1', 'MFAP1'),
#  ('HSPB1', 'TRIM54'),
#  ('HSPB1', 'SYCE1'),
#  ('HSPB1', 'NEXN'),
#  ('HSPB1', 'LIMK2'),
#  ('HSPB1', 'THOC5'),
#  ('HSPB1', 'UGDH'),
#  ('HSPB1', 'KCMF1'),
#  ('HSPB1', 'TARBP2'),
#  ('HSPB1', 'TNF'),
#  ('HSPB1', 'EIF1AX'),
#  ('HSPB1', 'KRT72'),
#  ('HSPB1', 'EPB41L2'),
#  ('HSPB1', 'ATP1A3'),
#  ('HSPB1', 'UFD1'),
#  ('HSPB1', 'PSMB2'),
#  ('HSPB1', 'TXNL1'),
#  ('HSPB1', 'IGBP1'),
#  ('HSPB1', 'FTH1'),
#  ('HSPB1', 'MPHOSPH6'),
#  ('HSPB1', 'OPTN'),
#  ('HSPB1', 'HECTD1'),
#  ('HSPB1', 'CIAO1'),
#  ('HSPB1', 'MED31'),
#  ('HSPB1', 'LASP1'),
#  ('HSPB1', 'PNISR'),
#  ('HSPB1', 'GRIPAP1'),
#  ('HSPB1', 'LSM3'),
#  ('AKT1', 'GAPDH'),
#  ('AKT1', 'STUB1'),
#  ('AKT1', 'SMAD3'),
#  ('AKT1', 'MDM2'),
#  ('AKT1', 'PPA1'),
#  ('AKT1', 'SRC'),
#  ('AKT1', 'NCOA4'),
#  ('AKT1', 'FOXO1'),
#  ('AKT1', 'SIRT1'),
#  ('AKT1', 'DDX5'),
#  ('AKT1', 'PTEN'),
#  ('AKT1', 'BRCA1'),
#  ('AKT1', 'ARNT'),
#  ('AKT1', 'CASP8'),
#  ('AKT1', 'KAT2B'),
#  ('AKT1', 'RAB5A'),
#  ('AKT1', 'TP53'),
#  ('AKT1', 'EGFR'),
#  ('AKT1', 'HDAC3'),
#  ('AKT1', 'PRKCZ'),
#  ('AKT1', 'AKT2'),
#  ('AKT1', 'IGF1R'),
#  ('AKT1', 'EEA1'),
#  ('AKT1', 'CTNNB1'),
#  ('AKT1', 'PIK3R1'),
#  ('AKT1', 'VCP'),
#  ('AKT1', 'RHEBL1'),
#  ('AKT1', 'TRAF6'),
#  ('AKT1', 'PIK3CA'),
#  ('AKT1', 'YWHAQ'),
#  ('AKT1', 'YWHAZ'),
#  ('AKT1', 'YWHAG'),
#  ('AKT1', 'AKTIP'),
#  ('AKT1', 'ENO1'),
#  ('AKT1', 'HSP90AA1'),
#  ('AKT1', 'ARRB2'),
#  ('AKT1', 'EP300'),
#  ('AKT1', 'PKM'),
#  ('AKT1', 'TUBB'),
#  ('AKT1', 'HSP90AB1'),
#  ('AKT1', 'MAP3K5'),
#  ('AKT1', 'CUL1'),
#  ('AKT1', 'YWHAE'),
#  ('AKT1', 'CDKN1A'),
#  ('AKT1', 'BCAR1'),
#  ('AKT1', 'SNCA'),
#  ('AKT1', 'SIRT6'),
#  ('AKT1', 'ESR1'),
#  ('AKT1', 'HTT'),
#  ('AKT1', 'CTBP1'),
#  ('AKT1', 'PTK2'),
#  ('AKT1', 'BCL2L1'),
#  ('AKT1', 'TBK1'),
#  ('AKT1', 'NPM1'),
#  ('AKT1', 'GJA1'),
#  ('AKT1', 'BPGM'),
#  ('AKT1', 'HSPA9'),
#  ('AKT1', 'ERBB2'),
#  ('AKT1', 'CDK4'),
#  ('AKT1', 'HSPA8'),
#  ('AKT1', 'ACTB'),
#  ('AKT1', 'ENO2'),
#  ('AKT1', 'GSK3B'),
#  ('AKT1', 'IRF3'),
#  ('AKT1', 'ATXN1'),
#  ('AKT1', 'CYLD'),
#  ('AKT1', 'CD81'),
#  ('AKT1', 'STK4'),
#  ('AKT1', 'ALDOA'),
#  ('AKT1', 'APP'),
#  ('AKT1', 'FKBP5'),
#  ('AKT1', 'SKP2'),
#  ('AKT1', 'MLH3'),
#  ('AKT1', 'PIK3R3'),
#  ('AKT1', 'CASP3'),
#  ('AKT1', 'PIAS1'),
#  ('AKT1', 'VHL'),
#  ('AKT1', 'GSK3A'),
#  ('AKT1', 'CDK6'),
#  ('AKT1', 'PPP2CA'),
#  ('AKT1', 'SMAD4'),
#  ('AKT1', 'INPPL1'),
#  ('AKT1', 'PPP1CA'),
#  ('AKT1', 'HIF1A'),
#  ('AKT1', 'CDC37'),
#  ('AKT1', 'SMARCC2'),
#  ('AKT1', 'NR3C1'),
#  ('AKT1', 'TNK2'),
#  ('AKT1', 'RELA'),
#  ('AKT1', 'NCOR2'),
#  ('AKT1', 'PIAS2'),
#  ('AKT1', 'LATS2'),
#  ('AKT1', 'PLCG1'),
#  ('AKT1', 'CREBBP'),
#  ('AKT1', 'SMARCC1'),
#  ('AKT1', 'EZH2'),
#  ('AKT1', 'FOXO3'),
#  ('AKT1', 'CCNE1'),
#  ('AKT1', 'PRKDC'),
#  ('AKT1', 'CTDSP2'),
#  ('AKT1', 'PRKCB'),
#  ('AKT1', 'PAK6'),
#  ('AKT1', 'BECN1'),
#  ('AKT1', 'STAT3'),
#  ('AKT1', 'RAF1'),
#  ('AKT1', 'PA2G4'),
#  ('AKT1', 'SMARCB1'),
#  ('AKT1', 'SREBF1'),
#  ('AKT1', 'ASXL1'),
#  ('AKT1', 'CDC42'),
#  ('AKT1', 'CSF2RB'),
#  ('AKT1', 'PDK1'),
#  ...]

# %% [markdown]
# #### we can write GGN into sif file

# %%
GRF.write_created_network("../AndrogenReceptor_GGN")
# Out:
# True

# %%
#### The calculation of graphlet frequencies may take long time. Thus, we can save frequencies or we can calculate in an exemplified pool.  In the downstream part, we can manually decide required graphlets.

# %%
GRF.save_frequencies_into_pickle("../AndrogenReceptor_Pool_Frequencies")

# %%
GRF.get_frequencies_from_pickle("../AndrogenReceptor_Pool_Frequencies.pickle")

# %%
GRF.get_Graphlet_Frequency()
# Out:
# {'Graphlets0': 0.0005076737368511812,
#  'Graphlets1': 0.03773616140713916,
#  'Graphlets2': 0.017971374374892223,
#  'Graphlets3': 0.5223535092257285,
#  'Graphlets4': 0.1784086911536472,
#  'Graphlets5': 0.08090774271426109,
#  'Graphlets6': 0.11248008277289188,
#  'Graphlets7': 0.03954750819106743,
#  'Graphlets8': 0.010087256423521297}

# %%
GRF.get_Graphlet_Frequency()
# Out:
# {'Graphlets0': 0.0005076737368511812,
#  'Graphlets1': 0.03773616140713916,
#  'Graphlets2': 0.017971374374892223,
#  'Graphlets3': 0.5223535092257285,
#  'Graphlets4': 0.1784086911536472,
#  'Graphlets5': 0.08090774271426109,
#  'Graphlets6': 0.11248008277289188,
#  'Graphlets7': 0.03954750819106743,
#  'Graphlets8': 0.010087256423521297}

# %%
Graphlet_list=list(Selected_Graphlets.keys())
Graphlet_list
# Out:
# ['Graphlets0',
#  'Graphlets2',
#  'Graphlets5',
#  'Graphlets6',
#  'Graphlets7',
#  'Graphlets8']

# %% [markdown]
# #### GGN construction with known graphlet-motifs

# %%
from Paragon import GraphletGuidance

# %%
GRF_lite=GraphletGuidance(HIPPIE_nx)

# %%
GGN_nx=GRF_lite.construct_GGN(initial_nodes,Graphlets=Graphlet_list,extention=False) # extension: True --> add existing interaction of hidden nodes in reference network 
## GGN_nx, Graph item in networkx
# Out:
# 82 of 82 input nodes have been found in the given network

# %%
GGN_nx.number_of_nodes()
# Out:
# 3246

# %%
GGN_df=nx.to_pandas_edgelist(GGN_nx)
GGN_df
# Out:
#                                                   source  target
# 0                                                  APPL1      AR
# 1                                                  APPL1    TP53
# 2                                                  APPL1    EGFR
# 3                                                  APPL1   HDAC3
# 4                                                  APPL1   HDAC2
# ...                                                  ...     ...
# 13552                                                SF1   CIAO1
# 13553  H3C1; H3C2; H3C3; H3C4; H3C6; H3C7; H3C8; H3C1...   KDM4C
# 13554                                       H3-3A; H3-3B   KDM4C
# 13555                                H3C15; H3C14; H3C13   KDM4C
# 13556                                              KDM4C  PDLIM5
#
# [13557 rows x 2 columns]

# %%
len(initial_nodes)
# Out:
# 82

# %% [markdown]
# ### PageRank Flux Calculations

# %% [markdown]
# Without guidance network, we can directly infer subnetwork from reference network through PageRankFlux algorithm.

# %%
## Weights of initial nodes
initial_weights=[1 for _ in initial_nodes]

# %%
from Paragon import NetworkInference

# %%
pgrf=NetworkInference(network=HIPPIE_nx,edge_attribute="Score")
pgrf.load_initial_nodes(list(initial_nodes))

# %% [markdown]
# ##### max_edge_count =>  limit the number of edge, the maximum number of edges with the higest flux scores
#
#
#
#
# ##### alpha => Damping parameter for PageRank, the propbability of walking into neighbors
#
#
# ##### threshold => the scaling factor, the threshold percentage of summed flux scores,
#              the algırithm select the edges from high to low flux scores by summing up the scores till completing intrested percentage
#
#
#
# ##### intermediate_only => True or False:
#                  True --> algorithm only select interactions in graphlet guided network between initial nodes.
#                  False --> algorithm select interactions in graphlet guided network unconsidering initial nodes.

# %%
returned_nx=pgrf.reconstruct_subnetwork( max_edge_count=2000,alpha=0.8,threshold=0.8,intermediate_only=True)
# Out:
# theshold of 0.087000 limits predictions to 2000 edges

# %%
returned_nx.number_of_edges()
# Out:
# 1636

# %%
# the number of interactions that are not located in initial node to initial node paths
2000-returned_nx.number_of_edges() #
# Out:
# 364

# %%
returned_df=nx.to_pandas_edgelist(returned_nx)
returned_df.to_csv('../AndrogenReceptor_recontructed_pathway_without_GGN.sif')

# %%
## Network inference with GraphletGudidedNetwork

# %%
pgrf=NetworkInference(network=HIPPIE_nx,guide_network=GGN_nx,edge_attribute="Score")
pgrf.load_initial_nodes(list(initial_nodes))

# %%
returned_nx=pgrf.reconstruct_subnetwork( max_edge_count=2000,alpha=0.8,threshold=0.8,intermediate_only=True)
# Out:
# theshold of 0.654000 limits predictions to 2000 edges

# %%
returned_nx.number_of_edges()
# Out:
# 1799

# %%
# the number of interactions that are not located in initial node to initial node paths
2000-returned_nx.number_of_edges() #
# Out:
# 201

# %%
returned_df=nx.to_pandas_edgelist(returned_nx)
returned_df.to_csv('../AndrogenReceptor_reconstructed_pathway_with_GGN.sif')

# %%
returned_df=pd.read_csv('../AndrogenReceptor_reconstructed_pathway_with_GGN.sif')
returned_nx=nx.from_pandas_edgelist(returned_df)
returned_nx.number_of_edges()
# Out:
# 1799

# %% [markdown]
# # Community detection

# %%
from Paragon import CommunityAnalysis

# %%
returned_df=pd.read_csv('../AndrogenReceptor_reconstructed_pathway_with_GGN.sif')
returned_nx=nx.from_pandas_edgelist(returned_df)
returned_nx.number_of_edges()
# Out:
# 1799

# %%
CA=CommunityAnalysis(returned_nx)

# %%
module_df, node_df=CA.get_communities_in_DataFrames()
node_df
# Out:
#       Genes  Community
# 0     RUNX2   Module_1
# 1     KLF13   Module_1
# 2     SMAD2   Module_1
# 3     KAT2B   Module_1
# 4      MSX2   Module_1
# ..      ...        ...
# 356  PPP1CA  Module_37
# 357  RNF123  Module_37
# 358   FBXO6  Module_37
# 359    PTK2  Module_37
# 360   ITGA4  Module_37
#
# [361 rows x 2 columns]

# %%
module_df
# Out:
#    Community_name                                          Community
# 0        Module_1              RUNX2;KLF13;SMAD2;KAT2B;MSX2;RB1;NFE4
# 1        Module_2  NCL;MDM2;FOXO1;SATB1;S100A2;FOXO4;ZNF550;MANF;...
# 2        Module_3  PNRC2;ATF2;POU2F2;GAPDH;CTNNB1;CEBPB;AR;SMARCA...
# 3        Module_4  FHL2;RELA;AHR;HSP90AA1;PSMC2;CDK9;PTEN;EGLN3;H...
# 4        Module_5                     XPO1;SEZ6L2;DLX5;FOXA1;ONECUT1
# 5        Module_6            MYOCD;AKT1;SMAD3;APP;STUB1;NR3C1;HOXC11
# 6        Module_7             PML;SUMO3;SIRT6;SENP1;PARP1;ARRB2;GCM1
# 7        Module_8    ZMIZ2;SLC39A7;SSX2; SSX2B;ARSJ;PIN1;PIAS1;MCPH1
# 8        Module_9                      TBP;PIAS3;TAB2;OPN1LW;PRPF40A
# 9       Module_10                  MECP2;RNF4;MAF;ZNF707;RBAK;ZNF420
# 10      Module_11           SLC30A9;SPDEF;NKX3-1;UNC119;PRDM16;STX16
# 11      Module_12                 NCOA4;HERC2;MAPK6;HIF1AN;TFG;GTF2B
# 12      Module_13  UBE2E3;UBE2D3;DACH1;GRAP2;DET1;RNF14;ETV5;MOV1...
# 13      Module_14  PIH1D1;UBB;RUVBL1;VHL;SKP2;PRPF8;SMURF2;UXT;PP...
# 14      Module_15  CDK4;CDKN1C;CDK5;RBX1;PPP1CB;CDKN1B;CDKN1A;CCN...
# 15      Module_16         ZNF160;RCHY1;UBE2D2;TNIP2;RBM38;CDK6;YWHAE
# 16      Module_17  NELFCD;TRIM68;VIM;KAT5;MTA1;IFI30;IGLL5;HNRNPL...
# 17      Module_18                  BRCA1;E2F1;CDK7;GTF2E1;CCNH;ERCC5
# 18      Module_19  HNRNPU;GTF2H3;GTF2H1;RPA3;RPA1;RPA2;RXRB;ERCC2...
# 19      Module_20  MNAT1;GTF2H2;UVSSA;GOLGA2;SRPK2;GTF2H2C; GTF2H...
# 20      Module_21  PSMC3IP;IL6ST;PIK3R2;GRB2;XRCC3;ERBB2;CDH1;CHE...
# 21      Module_22  NCOA2;ETV1;NCOA1;SP1;FOS;PGR;NR1I3;RARA;H4C1; ...
# 22      Module_23                THRB;HNRNPA1;BAG6;PRMT2;HNRNPK;ESR2
# 23      Module_24  ESRRG;PNRC1;RARB;NR5A2;RORB;HNF4A;NR0B2;HNF4G;...
# 24      Module_25  TRAF6;MAPT;NXF1;CBL;HSPA4;UBE2I;EFCAB6;BAG1;LR...
# 25      Module_26          PPARD;TXNRD2;HEY2;THRA;NCOR1;POU1F1;NR2E3
# 26      Module_27              APPL1;RUVBL2;HDAC5;HDAC3;TRAF2;ZNF829
# 27      Module_28  DDB1;CUL4B;IKBKB;ITSN2;CDC37;HDAC4;NR2C2;NR2C2...
# 28      Module_29  HOXA11;MNT;NEUROD1;GFI1;TBC1D32;TAL1;DNMT3L;HD...
# 29      Module_30  H3-3A; H3-3B;KDM4C;SFN;YWHAG;NCOR2;IKZF4;KDM4A...
# 30      Module_31                HUWE1;HDAC6;MED4;NFKB1;PPT1;DBT;DLD
# 31      Module_32  HSPB1;EGFR;TRIM25;SUMO1;EP300;EFTUD2;DDX5;UBE3...
# 32      Module_33                        VCAM1;RAN;FN1;CDK2;SF1;CFTR
# 33      Module_34  NCOA6;SPI1;JUN;CEBPA;EWSR1;GSK3B;MAPK8;BATF;PL...
# 34      Module_35  PPA1;UBE2M;FKBP4;OTUB1;CUL7;SIRT7;MAP1LC3A;GAB...
# 35      Module_36  MEPCE;CHD4;H3C1; H3C2; H3C3; H3C4; H3C6; H3C7;...
# 36      Module_37  GSN;TGFB1I1;PXN;CRKL;PIK3R1;CBLB;NEDD8;PPP1CA;...

# %%
#### Hypergeometric test for GOA

# %%
GOA_bio_proc_df=pd.read_csv(f'../Source/Annotations/GOA_proteins_isoforms_prepared.tab',sep="\t")
GOA_bio_proc_df
# Out:
#              GO ID DB Object Symbol
# 0       GO:0002250          IGKV3-7
# 1       GO:0002250        IGKV1D-42
# 2       GO:0002250         IGLV4-69
# 3       GO:0002250         IGLV8-61
# 4       GO:0002250         IGLV4-60
# ...            ...              ...
# 210592  GO:0006958             C1QA
# 210593  GO:0001682            RPP40
# 210594  GO:0061640            DCTN3
# 210595  GO:0045892           NELFCD
# 210596  GO:0006248           NT5C3A
#
# [210597 rows x 2 columns]

# %%
### hypergeometric test for a community

# %%
CA.hypergeometric_test_for_community("Module_36",
                                     reference_network=HIPPIE_nx,
                                           prior_knowledge_df=GOA_bio_proc_df,
                                           prior_knowledge_on="GO ID", 
                                           name_on="DB Object Symbol")
# Out:
#         GO ID   p-value  Erichment_Score  \
# 0  GO:0000122  0.000080         2.598862
# 1  GO:0006338  0.000009         4.291570
# 2  GO:0006357  0.509719        -1.002004
# 3  GO:0045892  0.001960         2.448193
# 4  GO:0045893  0.105222         1.030392
# 5  GO:0045944  0.292603        -0.056268
#
#                                      Genes in Module  \
# 0  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
# 1  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
# 2  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
# 3  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
# 4  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
# 5  [MEPCE, CHD4, H3C1,  H3C2,  H3C3,  H3C4,  H3C6...
#
#                                   Intersecting Genes  \
# 0  [HEXIM1, CHD3, SNW1, CUL3, LARP7, MEPCE, RNF2,...
# 1                  [TOP1, CHD3, CHD4, SMARCE1, RNF2]
# 2                             [SNW1, SMARCE1, CDC5L]
# 3                [HEXIM1, CHD3, SNW1, CHD4, SMARCE1]
# 4                              [CHD3, CHD4, SMARCE1]
# 5                               [SNW1, COPS5, CDC5L]
#
#   The number of intersecting genes  \
# 0                                8
# 1                                5
# 2                                3
# 3                                5
# 4                                3
# 5                                3
#
#                                         Process_Gene  \
# 0  [LINC-PINT, E2F8, FEZF1, CNOT1, NUPR2, HELT, N...
# 1  [ARID1A, CHD1, BTAF1, KDM6B, KDM6A, ZNHIT1, SM...
# 2  [MT-RNR1, EPOP, UNCX, ZNF98, ZNF716, ZNF724, Z...
# 3  [PRAMEF33, A0A0G2JP20, TLE7, PRAMEF22, PRAMEF2...
# 4  [TAF11L5, TAF11L4, TAF11L13, TAF11L14, TAF11L1...
# 5  [E2F8, ZBTB7C, NKX2-6, ZNF840P, HELT, MSGN1, N...
#
#   The number of components of prior_knowledge Community_name
# 0                                         968      Module_36
# 1                                         187      Module_36
# 2                                        1697      Module_36
# 3                                         587      Module_36
# 4                                         729      Module_36
# 5                                        1200      Module_36

# %%
returned_all=CA.hypergeometric_test_for_all_communities(reference_network=HIPPIE_nx,
                                           prior_knowledge_df=GOA_bio_proc_df,
                                           prior_knowledge_on="GO ID", 
                                           name_on="DB Object Symbol")
returned_all
# Out:
#     Community_name       GO ID       p-value  Erichment_Score  \
# 0         Module_1  GO:0006351  2.087920e-04         4.972020
# 1         Module_1  GO:0006355  1.916913e-05         4.594412
# 2         Module_1  GO:0006357  1.587277e-07         5.873635
# 3         Module_1  GO:0008285  1.262080e-05         5.276092
# 4         Module_1  GO:0045892  5.945193e-05         4.675598
# ..             ...         ...           ...              ...
# 236      Module_37  GO:0007165  1.278441e-02         2.115723
# 237      Module_37  GO:0016477  8.681411e-04         4.120524
# 238      Module_37  GO:0016567  4.650220e-04         3.635703
# 239      Module_37  GO:0034446  9.973064e-06         6.391448
# 240      Module_37  GO:0060396  9.422828e-08         8.752747
#
#                                        Genes in Module  \
# 0        [RUNX2, KLF13, SMAD2, KAT2B, MSX2, RB1, NFE4]
# 1        [RUNX2, KLF13, SMAD2, KAT2B, MSX2, RB1, NFE4]
# 2        [RUNX2, KLF13, SMAD2, KAT2B, MSX2, RB1, NFE4]
# 3        [RUNX2, KLF13, SMAD2, KAT2B, MSX2, RB1, NFE4]
# 4        [RUNX2, KLF13, SMAD2, KAT2B, MSX2, RB1, NFE4]
# ..                                                 ...
# 236  [GSN, TGFB1I1, PXN, CRKL, PIK3R1, CBLB, NEDD8,...
# 237  [GSN, TGFB1I1, PXN, CRKL, PIK3R1, CBLB, NEDD8,...
# 238  [GSN, TGFB1I1, PXN, CRKL, PIK3R1, CBLB, NEDD8,...
# 239  [GSN, TGFB1I1, PXN, CRKL, PIK3R1, CBLB, NEDD8,...
# 240  [GSN, TGFB1I1, PXN, CRKL, PIK3R1, CBLB, NEDD8,...
#
#                                 Intersecting Genes  \
# 0                             [SMAD2, NFE4, KAT2B]
# 1                 [RB1, NFE4, KAT2B, RUNX2, SMAD2]
# 2    [NFE4, KAT2B, RUNX2, KLF13, SMAD2, MSX2, RB1]
# 3                      [MSX2, SMAD2, KAT2B, KLF13]
# 4                        [RB1, MSX2, RUNX2, SMAD2]
# ..                                             ...
# 236                      [PXN, CRKL, CBLB, PIK3R1]
# 237                              [PXN, PTK2, CRKL]
# 238                   [CBLB, RNF123, FBXO6, NEDD8]
# 239                           [ITGA4, PIK3R1, PXN]
# 240                            [PIK3R1, PXN, PTK2]
#
#     The number of intersecting genes  \
# 0                                  3
# 1                                  5
# 2                                  7
# 3                                  4
# 4                                  4
# ..                               ...
# 236                                4
# 237                                3
# 238                                4
# 239                                3
# 240                                3
#
#                                           Process_Gene  \
# 0    [BCLAF3, LINC00473, AIP, TCERG1, POLR3A, BTAF1...
# 1    [ZNF722, A0A2R8YD15, FOXO3B, NFILZ, A0A7P0TAN4...
# 2    [MT-RNR1, EPOP, UNCX, ZNF98, ZNF716, ZNF724, Z...
# 3    [FEZF1, ZBTB7C, NUPR2, SULT2B1, MEN1, CACNB4, ...
# 4    [PRAMEF33, A0A0G2JP20, TLE7, PRAMEF22, PRAMEF2...
# ..                                                 ...
# 236  [CCL4L2, A0A2R8Y747, A0A499FJF3, ARHGAP10, PSD...
# 237  [PRSS37, FOXE1, PODXL, ITGB1BP1, LAMA5, ARPC5,...
# 238  [TMEM129, UBA6, ASB14, RFPL4A, MARCHF11, ZSWIM...
# 239  [NRP1, LAMA5, SRGAP2, FZD7, ABL1, FN1, ITGB3, ...
# 240  [SOCS2, JAK2, GH1, GHR, PIK3R1, STAT3, PXN, PT...
#
#     The number of components of prior_knowledge
# 0                                           294
# 1                                          1006
# 2                                          1697
# 3                                           396
# 4                                           587
# ..                                          ...
# 236                                        1293
# 237                                         261
# 238                                         522
# 239                                          58
# 240                                          13
#
# [241 rows x 9 columns]

# %% [markdown]
# ## significant modules in network

# %%
returned_all.Community_name.unique()
# Out:
# array(['Module_1', 'Module_2', 'Module_3', 'Module_4', 'Module_5',
#        'Module_6', 'Module_7', 'Module_10', 'Module_11', 'Module_13',
#        'Module_14', 'Module_15', 'Module_17', 'Module_18', 'Module_19',
#        'Module_20', 'Module_21', 'Module_22', 'Module_23', 'Module_24',
#        'Module_25', 'Module_26', 'Module_27', 'Module_28', 'Module_29',
#        'Module_30', 'Module_32', 'Module_34', 'Module_35', 'Module_36',
#        'Module_37'], dtype=object)
